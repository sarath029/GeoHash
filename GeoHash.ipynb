# %%
from polygon_geohasher.polygon_geohasher import polygon_to_geohashes, geohashes_to_polygon
from shapely import geometry

polygon = geometry.Polygon( 
            [
            [
              77.57150173187256,
              13.091433357957795
            ],
            [
              77.59411811828613,
              13.091433357957795
            ],
            [
              77.59411811828613,
              13.108194574636013
            ],
            [
              77.57150173187256,
              13.108194574636013
            ],
            [
              77.57150173187256,
              13.091433357957795
            ]
          ]
        )
inner_geohashes_polygon = polygon_to_geohashes(polygon, 7)

# %%
inner_geohashes_polygon
# Out:
# {'tdr4mpq',
#  'tdr4mpr',
#  'tdr4mpw',
#  'tdr4mpx',
#  'tdr4mpy',
#  'tdr4mpz',
#  'tdr4mr2',
#  'tdr4mr3',
#  'tdr4mr6',
#  'tdr4mr7',
#  'tdr4mr8',
#  'tdr4mr9',
#  'tdr4mrb',
#  'tdr4mrc',
#  'tdr4mrd',
#  'tdr4mre',
#  'tdr4mrf',
#  'tdr4mrg',
#  'tdr4mrk',
#  'tdr4mrm',
#  'tdr4mrq',
#  'tdr4mrr',
#  'tdr4mrs',
#  'tdr4mrt',
#  'tdr4mru',
#  'tdr4mrv',
#  'tdr4mrw',
#  'tdr4mrx',
#  'tdr4mry',
#  'tdr4mrz',
#  'tdr4mx2',
#  'tdr4mx3',
#  'tdr4mx6',
#  'tdr4mx7',
#  'tdr4mx8',
#  'tdr4mx9',
#  'tdr4mxb',
#  'tdr4mxc',
#  'tdr4mxd',
#  'tdr4mxe',
#  'tdr4mxf',
#  'tdr4mxg',
#  'tdr4mxk',
#  'tdr4mxm',
#  'tdr4mxs',
#  'tdr4mxt',
#  'tdr4mxu',
#  'tdr4mxv',
#  'tdr4t0n',
#  'tdr4t0p',
#  'tdr4t0q',
#  'tdr4t0r',
#  'tdr4t0w',
#  'tdr4t0x',
#  'tdr4t0y',
#  'tdr4t0z',
#  'tdr4t1n',
#  'tdr4t1p',
#  'tdr4t1q',
#  'tdr4t1r',
#  'tdr4t1w',
#  'tdr4t1x',
#  'tdr4t1y',
#  'tdr4t1z',
#  'tdr4t20',
#  'tdr4t21',
#  'tdr4t22',
#  'tdr4t23',
#  'tdr4t24',
#  'tdr4t25',
#  'tdr4t26',
# ...

# %%
import geohash

lat, lng = (13.091433357957795,77.59411811828613,) # 강남 Lat, Lng
gangnam = geohash.encode(lat, lng, 5)
decoded_location = geohash.decode(gangnam) 
print(gangnam)
# Out:
# tdr4m
